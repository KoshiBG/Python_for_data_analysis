# %% [markdown]
# <a href="https://colab.research.google.com/github/KoshiBG/Python_for_data_analysis/blob/main/6_1_4_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%94_%D0%B7%D0%B0%D0%B2%D0%B4%D0%B0%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BC%D0%BE%D0%B2%D0%BD%D0%B0_%D0%B9%D0%BC%D0%BE%D0%B2%D1%96%D1%80%D0%BD%D1%96%D1%81%D1%82%D1%8C_%D1%82%D0%B0_%D0%BD%D0%B5%D0%B7%D0%B0%D0%BB%D0%B5%D0%B6%D0%BD%D1%96_%D0%BF%D0%BE%D0%B4%D1%96%D1%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання №4
#
# **1.**  **З колоди у 52 карти випадково витягується одна карта. Яка ймовірність того, що це туз, якщо відомо, що ця карта — пікова?**
#
#    P ( A ∣ B )— ймовірність того, що подія  А(витягнута карта — туз) станеться за умови, що подія  Б(витягнута карта — пікова) вже відбулася,
#    P ( А ∩ B )— ймовірність того, що витягнута карта є і тузом, і піковою,
#    P ( B )— ймовірність того, що витягнута карта — пікова.
#
# 1. Знайдемо ймовірність
# P ( А ∩ B )
# Подія
# А
# ∩
# B
# відповідає витягненню пікового туза. У колоді є лише один піковий туз, тому ймовірність витягнути його з колоди з 52 картками дорівнює:
# P
# (
# А
# ∩
# B
# )
# =
# 1/
# 52
#
# 2. Знайдемо ймовірність
# P ( B )
# Подія
# B відповідає витягненню пікової карти. Оскільки в колоді є 13 піктограм, то ймовірність витягнути піктограму дорівнює:
# P
# (
# B
# )
# =
# 13/
# 52
#
# 3. Використовуємо формулу умовної ймовірності.
# Підставимо знайдені значення у формулу умовної ймовірності:
#
#   P
# (
# А
# ∣
# B
# )
# =
# P
# (
# А
# ∩
# B
# )/
# P
# (
# B
# )
# =
# (1/
# 52) :
# (13/
# 52)
# =
# 1/
# 13
# .

# %% [markdown]
# **2. У групі з 30 студентів є 18 хлопців і 12 дівчат. Відомо, що 7 хлопців і 5 дівчат носять окуляри. Випадково обраний студент носить окуляри. Яка ймовірність того, що цей студент — дівчина?**
#
#  А— подія, що обраний студент — дівчина,  B— подія, що обраний студент носити окуляри,
#
# P ( A ∣ B )— ймовірність того, що обраний студент — дівчина за умови, що він носить окуляри,
#
#  P ( А ∩ B )— ймовірність того, що обраний студент і дівчина, і носити окуляри,
#
# P ( B )— ймовірність того, що обраний студент носить окуляри.
#
# 1. Знайдемо
# P ( А ∩ B )
#
#     Подія
# А ∩ B відповідає тому, що обрана студентка — дівчина, яка носить окуляри. Відомо, що у 5 дівчат з 12 є окуляри, а загальна кількість студентів 30.
# Ця ймовірність відповідає кількості дівчат в окулярах поділеної на загальну кількість студентів
# (A ∩ B)=
# 5/30
#
# 2. ​Кількість студентів, у яких  є окуляри, дорівнює 12 (7 студентів і 5 дівчат),
# 𝑃
# (
# 𝐵
# )
# =
# 12/
# 30
#
# 3. 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# (5/
# 30)/
# (12/
# 30)
# =
# 5/
# 12
# Отже, ймовірність того, що випадково обраний студент, який носить окуляри, — це дівчина, дорівнює
# 5/
# 12
#
# ​

# %% [markdown]
# **3. У конверті знаходяться 10 лотерейних білетів, серед яких 3 виграшних. З конверта послідовно витягуються білети. Знайти ймовірності того, що:**
#
#   а) 2-й витягнутий білет буде виграшним, якщо 1-й був виграшним;
#
#   б) 3-й буде виграшним, якщо попередні два білети були виграшними;
#
#   в) 4-й буде виграшним, якщо попередні білети були виграшними.

# %% [markdown]
# **a)**   Ймовірність того, що 2-й витягнутий білет буде виграшним, якщо 1-й був
#    витягнутий
#    Після того, як ми витягли 1 виграшний білет (з 3 виграшних), у конверті залишилося 9 білетів, серед яких 2 виграшних. Отже, ймовірність того, що 2-й витягнутий білет буде виграшний
#
# 𝑃
# (
# 2-й виграшний
# ∣
# 1-й виграшний
# )
# =
# 2/
# 9
#
# **​б)** Ймовірність того, що 3-й буде виграшним, якщо попередні два білети були виграшними
# Якщо вже було витягнуто два виграшних білети, то в конверті залишилося 8 білетів, і тільки 1 з них є виграшним. Таким чином, ймовірність того, що 3-й білет буде виграшним:
#
# 𝑃
# (
# 3-й виграшний
# ∣
# 1-й і 2-й виграшні
# )
# =
# 1/
# 8
#
# **в)**
# Якщо вже витягнуто 3 виграшних білети (усі виграшні), то в конверті залишаються лише звичайні білети. Тому ймовірність того, що 4-й білет буде виграшним
# 𝑃
# (
# 4-й виграшний
# ∣
# 1-й, 2-й і 3-й виграшні
# )
# =
# 0
