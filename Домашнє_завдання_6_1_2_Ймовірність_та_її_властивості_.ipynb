# %% [markdown]
# <a href="https://colab.research.google.com/github/KoshiBG/Python_for_data_analysis/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%94_%D0%B7%D0%B0%D0%B2%D0%B4%D0%B0%D0%BD%D0%BD%D1%8F_6_1_2_%D0%99%D0%BC%D0%BE%D0%B2%D1%96%D1%80%D0%BD%D1%96%D1%81%D1%82%D1%8C_%D1%82%D0%B0_%D1%97%D1%97_%D0%B2%D0%BB%D0%B0%D1%81%D1%82%D0%B8%D0%B2%D0%BE%D1%81%D1%82%D1%96_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1.
# В урні знаходиться 15 білих, 5 червоних і 10 чорних куль. Випадковим чином витягується 1 куля, знайти ймовірність того, що вона буде:
# а) білою, б) червоною, в) чорною.

# %% [markdown]
# **1.   Загальна кількість куль:**
#
# Усього куль:
#
# 15 (білих)+5 (червоних)+10 (чорних)=30 куль.
# Ймовірність події — це відношення кількості сприятливих результатів до загальної кількості можливих результатів. Формула для ймовірності:
#
# **2.   Ймовірність витягнути білу кулю:**
#
# 𝑃(білої)
# =
# Кількість білих куль/
# Загальна кількість куль
#
# 𝑃(білої)
#  =
# 30/
# 15
# ​
#  =0.5
#
# **3. Ймовірність витягти червону кулю**
#
# 𝑃
# (
# червоної
# )
# =
# Кількість червоних куль/
# Загальна кількість куль
# =
# 5/
# 30
# =
# 1/
# 6
# ≈
# 0.1667
#
# **4.Ймовірність витягнути чорну кулю:**
#
# P(чорної)=
# Загальна кількість куль/
# Кількість чорних куль
# ​
#  =
# 10/30
#
# ​
#  =
# 1/3
# ​
#  ≈0.3333

# %% [markdown]
# # Завдання 2
# В магазин надійшло 30 холодильників, п'ять з яких мають заводський дефект. Випадковим чином обирають один холодильник. Яка ймовірність того, що він буде без дефекту?
#
# Холодильників з дефектом: 5.
#
# Холодильників без дефекту:
# 30−5=25.
#
# Ймовірність того, що вибраний холодильник буде без дефекту:
#
# Ймовірність обчислюється за формулою:
#
# 𝑃
# (
# без дефекту
# )
# =
# Кількість холодильників без дефекту/
# Загальна кількість холодильників
# =
# 25/
# 30
# =
# 5/
# 6
# ≈
# 0.8333

# %% [markdown]
# # Завдання 3
# Набираючи номер телефону, абонент забув дві останні цифри, але пам'ятає, що одна з них — нуль, а інша — непарна. Знайти ймовірність того, що він набере правильний номер.
#
#
#
# **1.   Визначимо всі можливі варіанти:**
#
# Абонент пам'ятає, що дві останні цифри номера: одна — 0, а інша — непарна.
# Непарні цифри:
# {
# 1
# ,
# 3
# ,
# 5
# ,
# 7
# ,
# 9
# }
# {1,3,5,7,9}.
# Дві цифри можуть бути розміщені в будь-якому порядку: одна позиція для 0, інша для непарної цифри.
#
#  **2.  Кількість всіх можливих варіантів:**
#
# Маємо дві позиції для цифр. Одна з них буде зайнята нулем, інша — однією з непарних цифр.
# Можливі позиції для 0: 2 (0 може стояти або на першому, або на другому місці).
# Для кожного варіанту позиції для 0, є 5 варіантів для непарної цифри.
# Тому загальна кількість можливих варіантів:
# 2
# ×
# 5
# =
# 10
# 2×5=10.
#
# **3. Сприятливі варіанти:**
#
# Є тільки один правильний варіант — це коли абонент набере дві останні цифри точно в правильному порядку.
#
# **4. Ймовірність правильного набору:**
#
# Ймовірність події обчислюється як відношення кількості сприятливих варіантів до кількості всіх можливих варіантів.
#
# P(правильний номер)=
# Загальна кількість варіантів/
# Кількість сприятливих варіантів
# ​
#  =
# 1/10
# ​
#  =0.1 або 10%

# %% [markdown]
# # Завдання 4
#
# 4. Знайти ймовірність того, що при кидку двох гральних кубиків добуток чисел на них:
#
#   а) дорівнюватиме семи;
#
#   б) буде не меншим за 20;
#
#   в) буде парним.

# %% [markdown]
# Кожен з двох гральних кубиків має 6 граней із числами від 1 до 6. Всього існує
#
# 6×6=36 можливих комбінацій чисел при одночасному кидку двох кубиків.
#
# **а) Ймовірність того, що добуток чисел дорівнюватиме 7**
#
#
# Щоб знайти можливі комбінації, при яких добуток чисел на кубиках дорівнює 7, розглянемо рівняння:
#
# 𝑥
# ×
# 𝑦
# =
# 7
#
# Можливі комбінації:
#
# 1
# ×
# 7
#  — неможливо, оскільки числа на кубиках від 1 до 6.
#
# 7×1 — також неможливо.
#
# Єдина можлива комбінація:
# 7
# 1×7 або
#
# 7×1 неможливі, тому немає жодної комбінації.
# Висновок: не існує комбінацій, за яких добуток чисел дорівнює 7. Отже, ймовірність дорівнює 0.
#
# **б) Ймовірність того, що добуток чисел буде не меншим за 20**
#
# Тут нам потрібно знайти всі комбінації чисел
#
# x × y ≥ 20.
#
# Перевіримо можливі добутки:
#
# 4×5=20
#
# 4×6=24
#
# 5×4=20
#
# 5×5=25
#
# 5×6=30
#
# 6×4=24
#
# 6×5=30
#
# 6×6=36
# Сприятливі варіанти:
# (
# 4
# ,
# 5
# )
# ,
# (
# 4
# ,
# 6
# )
# ,
# (
# 5
# ,
# 4
# )
# ,
# (
# 5
# ,
# 5
# )
# ,
# (
# 5
# ,
# 6
# )
# ,
# (
# 6
# ,
# 4
# )
# ,
# (
# 6
# ,
# 5
# )
# ,
# (
# 6
# ,
# 6
# )
#
# Всього є 8 сприятливих комбінацій.
#
# Ймовірність:
#
# 𝑃
# (
# добуток
# ≥
# 20
# )
# =
# 8/
# 36
# =
# 2/
# 9
# ≈
# 0.2222

# %% [markdown]
# **в) Ймовірність того, що добуток буде парним**
#
# Щоб добуток двох чисел був парним, хоча б одне з чисел повинно бути парним. Парні числа на кубиках: 2,4,6.
#
# Для кожного значення першого кубика (6 можливостей) маємо 3 можливості для парного другого числа: 2,4,6.
#
# Таким чином, можемо знайти всі можливі комбінації.
#
# Непарні варіанти: розглянемо тільки ті випадки, коли обидва числа непарні:
#
# 1
# ×
# 1
# ,
# 1
# ×
# 3
# ,
# 1
# ×
# 5
# ,
# 3
# ×
# 1
# ,
# 3
# ×
# 3
# ,
# 3
# ×
# 5
# ,
# 5
# ×
# 1
# ,
# 5
# ×
# 3
# ,
# 5
# ×
# 5
#  — всього 9 варіантів.
#  Загальна кількість парних варіантів буде:
# 36−9=27
#
# Ймовірність:
# P(парний добуток)=
# 27/36
#  =
# 3/4
# ​ = 0.75

# %% [markdown]
# # Задача 5
#
# Ймовірність того, що на тесті з біології учень О. правильно розв'яже більше 11 задач, дорівнює 0,67. Ймовірність того, що О. правильно розв'яже більше 10 задач, дорівнює 0,74. Знайдіть ймовірність того, що О. правильно розв'яже рівно 11 задач.
#
# Нехай:
#
# P(X>11)=0.67 — ймовірність того, що учень О. розв'яже більше 11 задач.
#
# P(X>10)=0.74 — ймовірність того, що учень О. розв'яже більше 10 задач.
# Нам потрібно знайти ймовірність того, що учень О. розв'яже рівно 11 задач.

# %% [markdown]
# Ймовірність того, що учень О. розв'яже більше 10 задач, включає випадки, коли він розв'язує 11, 12, 13 і більше задач. Це можна записати як:
#
# P(X>10)=P(X=11)+P(X>11)
#
# Відповідно, можемо знайти ймовірність
#
# P(X=11) за формулою:
#
#
# P(X=11)=P(X>10)−P(X>11)
#
# P(X=11)=0.74−0.67=0.07
