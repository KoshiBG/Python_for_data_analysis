# %% [markdown]
# <a href="https://colab.research.google.com/github/KoshiBG/Python_for_data_analysis/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%94_%D0%B7%D0%B0%D0%B2%D0%B4%D0%B0%D0%BD%D0%BD%D1%8F_5__6_1_5_%D0%A2%D0%B5%D0%BE%D1%80%D0%B5%D0%BC%D0%B0_%D0%91%D0%B0%D1%94%D1%81%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. У медичному центрі проводять тест на певну хворобу. Відомо, що 1% населення страждає на цю хворобу. Тест дає позитивний результат у 99% випадків для хворих і 5% випадків для здорових людей (хибнопозитивний результат). Якщо тест показав позитивний результат, яка ймовірність того, що людина насправді хвора?**
#
# Позначимо події:
#
#
# A — подія, що людина хвора.
#
# ¬A — подія, що людина здорова.
#
# B — подія, що тест дав позитивний результат.
# Маємо такі ймовірності:
#
# P(A)=0.01 — ймовірність того, що людина хвора.
#
# P(¬A)=0.99 — ймовірність того, що людина здорова.
#
# P(B∣A)=0.99 — ймовірність позитивного тесту, якщо людина хвора (чутливість тесту).
#
# P(B∣¬A)=0.05 — ймовірність позитивного тесту для здорової людини (хибнопозитивний результат).
#
# P(B) — загальна ймовірність позитивного результату тесту.
#
# Загальна ймовірність того, що тест показав позитивний результат, може бути розрахована як сума двох можливостей:
#
# Людина хвора, і тест дав правильний результат.
# Людина здорова, але тест дав хибнопозитивний результат.
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝐴
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# ¬
# 𝐴
# )
# 𝑃
# (
# ¬
# 𝐴
# )
#
# P(B)=0.99⋅0.01+0.05⋅0.99=0.0099+0.0495=0.0594
#
# Тепер можемо обчислити умовну ймовірність того, що людина хвора, якщо тест позитивний:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# =
# 0.99
# ⋅
# 0.01/
# 0.0594
# =
# 0.0099/
# 0.0594
# ≈
# 0.1667
#
# Отже, ймовірність того, що людина насправді хвора при позитивному результаті тесту, становить приблизно 16.67%.

# %% [markdown]
# *2. У компанії 70% співробітників чесні, а 30% можуть інколи брехати. Детектор брехні правильно ідентифікує чесних співробітників у 90% випадків і неправильно класифікує їх як таких, що брехали, у 10% випадків. Якщо детектор показав, що співробітник брехав, яка ймовірність того, що він насправді брехав?*
#
# Позначимо події:
#
# A — співробітник брехун.
#
# B — детектор показав, що співробітник брехав.
#
# Ми шукаємо ймовірність
# P(A∣B), тобто ймовірність того, що співробітник брехун, якщо детектор показав, що він брехав.
#
# P(A)=0.30 — ймовірність того, що співробітник брехун (30%).
#
# P(¬A)=0.70 — ймовірність того, що співробітник чесний (70%).
#
# P(B∣A)=1 — ймовірність того, що детектор правильно ідентифікував брехуна як такого, що брехав (зазвичай 100%, але це може бути уточнено в майбутніх задачах).
#
# P(B∣¬A)=0.10 — ймовірність того, що детектор помилково ідентифікував чесного співробітника як такого, що брехав (10%).
#
# Обчислимо
# P(B) — загальну ймовірність того, що детектор покаже брехню.
# Це може статися в двох випадках:
#   Співробітник справді брехун, і детектор правильно його ідентифікував.
# Співробітник чесний, але детектор помилково показав брехню.
#
# P(B)=P(B∣A)P(A)+P(B∣¬A)P(¬A)
#
# Підставимо значення:
# P(B)=1 * 0.30+0.10 * 0.70 = 0.30+0.07 = 0.37
#
# Тепер можемо знайти умовну ймовірність:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝐴
# )/
# 𝑃
# (
# 𝐵
# )
# =
# 1
# *
# 0.30/
# 0.37
# =
# 0.30/
# 0.37
# ≈
# 0.81
# Отже, ймовірність того, що співробітник справді брехун, якщо детектор показав, що він брехав, становить приблизно 81%.

# %% [markdown]
# *3. Відомо, що предмет можна загубити в одній з трьох кімнат: у першій кімнаті з ймовірністю 0,5, у другій — з ймовірністю 0,3, і в третій — з ймовірністю 0,2. Якщо предмет загублено в кімнаті, ймовірність знайти його під час пошуку складає 0,8 для першої кімнати, 0,6 для другої і 0,4 для третьої. Якщо предмет знайшли, яка ймовірність того, що його було загублено в першій кімнаті?*
#
# Позначимо події:
#
#
# A
# 1
# ​
#   — предмет загублено в першій кімнаті,
#
# B — предмет знайдено.
#
# Ми шукаємо умовну ймовірність
# 𝑃
# (
# 𝐴
# 1
# ∣
# 𝐵
# )
#  — ймовірність того, що предмет загублено в першій кімнаті, якщо його знайшли.
#
#  Відомі ймовірності:
# 𝑃
# (
# 𝐴
# 1
# )
# =
# 0.5
#  — ймовірність, що предмет загублено в першій кімнаті.
# 𝑃
# (
# 𝐴
# 2
# )
# =
# 0.3
#  — ймовірність, що предмет загублено в другій кімнаті.
# 𝑃
# (
# 𝐴
# 3
# )
# =
# 0.2
#  — ймовірність, що предмет загублено в третій кімнаті.
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 1
# )
# =
# 0.8
#  — ймовірність знайти предмет у першій кімнаті.
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 2
# )
# =
# 0.6
#  — ймовірність знайти предмет у другій кімнаті.
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 3
# )
# =
# 0.4
#  — ймовірність знайти предмет у третій кімнаті.
#
#  Загальна ймовірність знайти предмет — це сума ймовірностей знайти його в кожній кімнаті:
#
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 1
# )*
# 𝑃
# (
# 𝐴
# 1
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 2
# )*
# 𝑃
# (
# 𝐴
# 2
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 3
# )*
# 𝑃
# (
# 𝐴
# 3
# )
#
# Підставимо значення:
#
# P(B)=0.8 * 0.5+0.6 * 0.3+0.4 * 0.2=0.4+0.18+0.08=0.66
#
# Знайдемо
#
# P(A
# 1
# ​
#  ∣B)=
# 0.8*0.5/0.66
# ≈0.606
#
# Отже, ймовірність того, що предмет було загублено в першій кімнаті, якщо його знайшли, становить приблизно 60.6%.

# %% [markdown]
# *4. На заводі виробляють продукцію на трьох лініях: 50% продукції випускає перша лінія, 30% — друга, і 20% — третя. Відомо, що 2% продукції з першої лінії, 3% з другої і 5% з третьої мають дефекти. Якщо випадково обрана продукція має дефект, яка ймовірність того, що вона була випущена третьою лінією?*
#
# Позначимо події:
#
# A
# 3-
# ​ продукція випущена третьою лінією,
#
# B — продукція має дефект.
#
# Ми шукаємо умовну ймовірність
# 𝑃
# (
# 𝐴
# 3
# ∣
# 𝐵
# ), тобто ймовірність того, що продукція випущена третьою лінією за умови, що вона має дефект.
#
# Відомі ймовірності:
# 𝑃
# (
# 𝐴
# 1
# )
# =
# 0.50 — ймовірність, що продукція випущена першою лінією,
#
# 𝑃
# (
# 𝐴
# 2
# )
# =
# 0.30— ймовірність, що продукція випущена другою лінією,
#
# 𝑃
# (
# 𝐴
# 3
# )
# =
# 0.20 — ймовірність, що продукція випущена третьою лінією,
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 1
# )
# =
# 0.02 — ймовірність того, що продукція з першої лінії має дефект,
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 2
# )
# =
# 0.03 — ймовірність того, що продукція з другої лінії має дефект,
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 3
# )
# =
# 0.05 — ймовірність того, що продукція з третьої лінії має дефект.
#
# Знайдемо
# P(B):
# Загальна ймовірність того, що продукція має дефект — це сума ймовірностей дефектної продукції з кожної лінії:
# P(B)=P(B∣A
# 1
# ​
#  )P(A
# 1
# ​
#  )+P(B∣A
# 2
# ​
#  )P(A
# 2
# ​
#  )+P(B∣A
# 3
# ​
#  )P(A
# 3
# ​
#  )
#
# P(B)=0.02⋅0.50+0.03⋅0.30+0.05⋅0.20=0.01+0.009+0.01=0.029
#
# Знайдемо
# 𝑃
# (
# 𝐴
# 3
# ∣
# 𝐵
# )
# =
# 0.05
# *
# 0.20/
# 0.029
# =
# 0.01/
# 0.029
# ≈
# 0.3448
#
# Отже, ймовірність того, що продукція з дефектом була випущена третьою лінією, становить приблизно 34.48%.

# %% [markdown]
# *5. Програма для розпізнавання рукописних цифр має точність 95% для цифри "3" і 98% для інших цифр. Якщо на вхід програми подано цифру "3", а програма її не розпізнала, яка ймовірність того, що насправді була подана цифра "3"? Відомо, що в 20% випадків на вхід подається цифра "3".*
#
# Позначимо події:
#
# A 3 — на вхід подана цифра "3",
#
# B — програма не розпізнала цифру "3".
#
# Ми шукаємо умовну ймовірність
# 𝑃
# (
# 𝐴
# 3
# ∣
# 𝐵
# ), тобто ймовірність того, що насправді була подана цифра "3", якщо програма не розпізнала цифру.
#
# Відомі імовірності:
#
#  P(A
# 3
# ​
#  )=0.20 — ймовірність того, що на вхід подано цифру "3" (20% випадків),
#
#  P(¬A
# 3
# ​
#  )=0.80 — ймовірність того, що на вхід подана інша цифра (80% випадків),
#
#  P(B∣A
# 3
# ​
#  )=0.05 — ймовірність того, що програма не розпізнала цифру "3" (тобто помилилася у випадку з "3", оскільки точність 95%),
#
#  P(B∣¬A
# 3
# ​
#  )=0.02 — ймовірність того, що програма не розпізнала іншу цифру (тобто помилилася у випадку з іншими цифрами, оскільки точність 98%).
#
#  Знайдемо
# P(B) — загальну ймовірність того, що програма не розпізнала цифру:
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# 3
# )
# 𝑃
# (
# 𝐴
# 3
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# ¬
# 𝐴
# 3
# )
# 𝑃
# (
# ¬
# 𝐴
# 3
# )
#
# P(B)=0.05 * 0.20+0.02 * 0.80=0.01+0.016=0.026
#
# P(A
# 3
# ​
#  ∣B)=
# 0.05⋅0.20/0.026
# ≈0.3846
# Отже, ймовірність того, що насправді була подана цифра "3", якщо програма не розпізнала цифру, становить приблизно 38.46%.
