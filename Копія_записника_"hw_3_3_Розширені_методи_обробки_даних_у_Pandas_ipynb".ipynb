# %% [markdown]
# <a href="https://colab.research.google.com/github/KoshiBG/Python_for_data_analysis/blob/main/%D0%9A%D0%BE%D0%BF%D1%96%D1%8F_%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D0%BD%D0%B8%D0%BA%D0%B0_%22hw_3_3_%D0%A0%D0%BE%D0%B7%D1%88%D0%B8%D1%80%D0%B5%D0%BD%D1%96_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%B8_%D0%BE%D0%B1%D1%80%D0%BE%D0%B1%D0%BA%D0%B8_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85_%D1%83_Pandas_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання до теми "Розширені методи обробки даних у Pandas"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import numpy as np
import pandas as pd

# %%
data_path = '../content/drive/MyDrive/code/data/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %%
# Додавання нижнього підкреслення до назв колонок.Зручніше, як на мене))

df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# 1. Відсортуйте дані за спаданням ціни товара ('Unit price') і виведіть 5 перших рядочків на екран.

# %%
df.sort_values(by="Unit_price", ascending=False).head()
# Out:
#       Invoice_ID Branch       City Customer_type Gender         Product_line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member   Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal   Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal   Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member   Male    Health and beauty
#
#      Unit_price  Quantity  Tax_5%    Total       Date   Time      Payment  \
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 930       99.92         6  29.976  629.496  3/24/2019  13:33      Ewallet
# 494       99.89         2   9.989  209.769  2/26/2019  11:48      Ewallet
# 283       99.83         6  29.949  628.929   3/4/2019  15:02      Ewallet
#
#        cogs  gross_margin_percentage  gross_income  Rating
# 983  699.72                 4.761905        34.986     6.1
# 122  899.64                 4.761905        44.982     4.2
# 930  599.52                 4.761905        29.976     7.1
# 494  199.78                 4.761905         9.989     7.1
# 283  598.98                 4.761905        29.949     8.5

# %% [markdown]
# 2. Знайдіть інвойс (рядок в даних) в категорії товарів Electronic accessories, в якому був куплений товар з найбільшою кількістю і найбільшою ціною. Виведіть цей рядок даних на екран.

# %%
# Фільтрація інвойсів для категорії 'Electronic accessories' та ранжування по  максимальним значенням 'Unit_price' і 'Quantity'

electronic_accessories = df[df['Product_line'] == 'Electronic accessories'].sort_values(by=['Unit_price', 'Quantity'], ascending=[False,False]).head(1)
display(electronic_accessories)
# Out:
#       Invoice_ID Branch      City Customer_type  Gender  \
# 209  817-69-8206      B  Mandalay        Normal  Female
#
#                Product_line  Unit_price  Quantity   Tax_5%     Total  \
# 209  Electronic accessories       99.73         9  44.8785  942.4485
#
#          Date   Time      Payment    cogs  gross_margin_percentage  \
# 209  3/2/2019  19:42  Credit card  897.57                 4.761905
#
#      gross_income  Rating
# 209       44.8785     6.5

# %% [markdown]
# 3.1. Створіть нову колонку в даних `Rating Category`, яка визначає категорію рейтингу: високий, середній чи низький за наступним правилом:
# - якщо рейтинг вищий або рівний 8 - то він високий (`High`)
# - якщо рейтинг від 6 до 8 не включаючи - то він середній (`Medium`)
# - інакше - низький (`Low`).

# %%
# Функція для визначення категорії рейтингу

def categorize_rating(Rating):
    if Rating >= 8:
        return 'High'
    elif 6 <= Rating < 8:
        return 'Medium'
    else:
        return 'Low'

# Створення нової колонки 'Rating_Category'

df['Rating_Category'] = df.Rating.apply(categorize_rating).head()

display(df)
# Out:
#       Invoice_ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity   Tax_5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross_margin_percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross_income  Rating Rating Category Rating_Category
# 0         26.1415     9.1            High            High
# 1          3.8200     9.6            High            High
# 2         16.2155     7.4          Medium          Medium
# 3         23.2880     8.4            High            High
# 4         30.2085     5.3             Low             Low
# ..            ...     ...             ...             ...
# 995        2.0175     6.2          Medium             NaN
# 996       48.6900     4.4             Low             NaN
# 997        1.5920     7.7          Medium             NaN
# 998        3.2910     4.1             Low             NaN
# 999       30.9190     6.6          Medium             NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# 3.2. Виведіть, який відсоток даних становить кожне зі значень категорій рейтингу.

# %%
# Обчислення відсотка для кожної категорії рейтингу

rating_percentage = df['Rating_Category'].value_counts(normalize=True) * 100
display(rating_percentage)
# Out:
# Rating_Category
# High      60.0
# Medium    20.0
# Low       20.0
# Name: proportion, dtype: float64

# %% [markdown]
# 4.1. Запустіть код нижче аби створити змінну `time`. Ця змінна містить час в форматі "година:хвилина". Напишіть функцію `get_hour`, яка буде зі змінної формату як `time` дістати лише години і конвертувати їх у тип `int`.
#
# Запустіть написану функцію на змінній `time` та перевірте правильність роботи функції.

# %%
time = '11:28'

# %%
def get_hour(x):
  hour, minute = x.split(':')
  return int(hour)

get_hour(time)
# Out:
# 11

# %% [markdown]
# 4.2. З допомогою функції `get_hour` і метода `DataFrame.apply()` створіть нову колонку `Hour` в нашому наборі даних, яка буде містити години здійснення покупки, обчислені на основі часу здійснення покупки `Time`.

# %%
df['Hour'] = df.Time.apply(get_hour)
df['Hour'].head()
# Out:
# 0    13
# 1    10
# 2    13
# 3    20
# 4    10
# Name: Hour, dtype: int64

# %% [markdown]
# 4.3. Виведіть кількість значень за кожною годиною покупки і дайте відповідь "О яких годинах найбільше здійснюють покупок покупці і чому на Ваш погляд саме о цих годинах? Чи це слогічно, що найбільше покупок саме в ці години?".

# %%
df.Hour.value_counts()
# Out:
# Hour
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# Name: count, dtype: int64

# %% [markdown]
# Найбільш покупок, це час в перші години після відкриття 10, обідня перерва 13, час після закінчення робочого часу 19. 15- спірне питання, можливо школяри, студенти після закінчення навчання.

# %% [markdown]
# 5. Виведіть середнє значення чеку (`Total`) для покупок в містах, наявних в даних, за допомогою функції `groupby`.

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'Rating', 'Rating Category', 'Rating_Category', 'Hour'],
#       dtype='object')

# %%
df.groupby('City')['Total'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %% [markdown]
# 6. Виведіть кількість покупок, середнє, мінімальне та максимальне значення для загальної суми чеку (Total) в містах, наявних в даних, за допомогою функції groupby.
# Зробіть висновки з цих показників та дайте рекомендації для мережі супермаркетів.

# %%
df.groupby('City')['Total'].agg(['size', 'mean', 'min', 'max'])
# Out:
#            size        mean      min      max
# City
# Mandalay    332  319.872506  18.6375  1022.49
# Naypyitaw   328  337.099715  10.6785  1042.65
# Yangon      340  312.354031  12.6945  1039.29

# %% [markdown]
# 1. Оптимізуйте асортимент і ціноутворення:
# Низькодохідні транзакції: У всіх містах є транзакції з дуже низьким доходом. Проаналізуйте, які товари або категорії товарів мають такі низькі доходи, і розгляньте можливість підвищення цін або зміни асортименту, щоб підвищити загальний дохід.
# Акції та знижки: Розгляньте акції, спрямовані на підвищення доходу в містах, де середній дохід нижчий. Це може бути досягнуто через комбінації продуктів або спеціальні пропозиції для залучення клієнтів.
# 2. Сегментуйте ринки та підлаштовуйте маркетинг:
# Yangon: Місто з найвищим максимальним доходом. Можливо, в цьому місті є сегменти споживачів, які готові платити більше за преміум-продукти. Рекомендується зосередитися на маркетингу таких продуктів і підсилити наявність преміум-товарів.
# Naypyitaw: Місто з найвищим середнім доходом. Розгляньте можливість реклами або акцій, що підсилюють враження від покупок, наприклад, покращення обслуговування клієнтів або впровадження програм лояльності.
# Mandalay: Місто з хорошим середнім доходом, але з великим діапазоном між мінімальним і максимальним доходом. Тут можуть працювати персоналізовані акції або гнучке ціноутворення.

# %% [markdown]
# 7. Ми внесли деякі зміни в наш набір даних, тож, давайте запишемо результат у файл. Запишіть оновлену версію даних у файл `supermarket_sales_enriched.csv`. Зверніть увагу, аби не записати нічого зайвого, наприклад, індекси рядків нам в файлі не потрібні, оскільки вони стандартні.

# %%
df.to_csv('supermarket_sales_enriched.csv', index=False)
pd.read_csv('supermarket_sales_enriched.csv', nrows=3)
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#   Rating Category Rating_Category  Hour
# 0            High            High    13
# 1            High            High    10
# 2          Medium          Medium    13
